# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
temperatures = [22, 23, 24, 22, 20, 19, 21]

fig, ax1 = plt.subplots()
ax1.plot(days, temperatures, marker='X', linestyle='--', markerfacecolor="red", color='b')
plt.show()

# %%
math_scores = [85, 70, 92, 78, 88, 95, 60, 75, 85, 70]
science_scores = [75, 65, 88, 72, 80, 92, 55, 70, 78, 68]

plt.scatter(science_scores, math_scores, c="red", marker="X", label="Students")
plt.title("Scatter graph")
plt.xlabel("Science")
plt.ylabel("Math")
plt.legend()
plt.grid(True)
plt.show()

# %%
scores = np.array([2,2,2,2,2,3,3,4,5,5,5,6,6,6,6,6,6],dtype="int")
plt.hist(scores, bins=5, edgecolor="black", color="yellow")
plt.ylabel("Number of Students")
plt.xlabel("Socres")
plt.title("Histogram")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\pythoncourse\homework\graphs\all.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/pythoncourse/homework/graphs/all.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> scores = np.array([2,2,2,2,2,3,3,4,5,5,5,6,6,6,6,6,6],dtype="int")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/pythoncourse/homework/graphs/all.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> plt.hist(scores, bins=5, edgecolor="black", color="yellow", binwidth=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/pythoncourse/homework/graphs/all.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> plt.ylabel("Number of Students")
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/pythoncourse/homework/graphs/all.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel("Socres")
#
# ...
